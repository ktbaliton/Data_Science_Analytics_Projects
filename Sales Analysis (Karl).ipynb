# %% [markdown]
# # Sales Analysis

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import os
import glob

# %% [markdown]
# ### Task 1: Merge the 12 months of sales data into a single CSV file

# %% [markdown]
# #### Solution from online search

# %%
#Change directory to "Sales_Data"
os.chdir('Sales_Data')

# use glob to get all the csv files 
# in the folder
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
  
  
# loop over the list of csv files
for f in csv_files:
      
    # read the csv file
    df = pd.read_csv(f)
      
    # print the location and filename
    print('Location:', f)
    print('File Name:', f.split("\\")[-1])
      
    # print the content
    print('Content:')
    display(df)
    print()

#Return to previous directory
os.chdir("..")
# Out:
# Location: C:\Users\ktbaliton518\Desktop\Data Analytics\Python Pandas Exercise (Keith Galli)\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_April_2019.csv
# File Name: Sales_April_2019.csv
# Content:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# ...

# %% [markdown]
# #### Solution of Keith

# %%
#Collect file names
files = [file for file in os.listdir('./Sales_Data')]

#Print each file name
for file in files:
    print(file)
# Out:
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %%
#Collect file names
files = [file for file in os.listdir('./Sales_Data')]

#Create empty dataframe
all_months_data = pd.DataFrame()

#Read each file and then concatenate in one dataframe
for file in files:
    df = pd.read_csv('./Sales_Data/' + file)
    all_months_data = pd.concat([all_months_data,df])

#Create csv file for combined data
all_months_data.to_csv("all_data.csv", index=False)

# %% [markdown]
# #### Read in updated dataframe

# %%
#Read csv file of combined data
all_data = pd.read_csv("all_data.csv")
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Task 2: Clean the data

# %% [markdown]
# #### Drop rows with NaN

# %%
all_data.dropna(inplace=True)
all_data.reset_index(drop=True, inplace=True)
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186300   259353      AAA Batteries (4-pack)                3       2.99
# 186301   259354                      iPhone                1        700
# 186302   259355                      iPhone                1        700
# 186303   259356      34in Ultrawide Monitor                1     379.99
# 186304   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Augment data with additional columns

# %% [markdown]
# #### Subtask: Add a "Month" Column

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data
# Out:
# <ipython-input-12-b900d107a7ed>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = all_data['Order Date'].str[0:2]
# <ipython-input-12-b900d107a7ed>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = all_data['Month'].astype('int32')
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# ...

# %% [markdown]
# #### Subtask: Remove data with "Or" in Order Date column

# %%
#ValueError: invalid literal for int() with base 10: 'Or'
#Find data that has "Or" value in Order Date column
temp_df = all_data[all_data['Order Date'].str[0:2] == "Or"] 
temp_df.head()

#23:45 continue
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 517   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1146  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1152  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2869  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2884  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address
# 517   Purchase Address
# 1146  Purchase Address
# 1152  Purchase Address
# 2869  Purchase Address
# 2884  Purchase Address

# %%
#Instead of delete data with "Or", reset dataframe using not equal
all_data = all_data[all_data['Order Date'].str[0:2] != "Or"] 
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# #### Subtask: Add a "Sales" column

# %%
all_data['Sales'] = all_data['Quantity Ordered']*all_data['Price Each']
all_data.head()
# Out:
# <ipython-input-18-249120f4cbc4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Sales'] = all_data['Quantity Ordered']*all_data['Price Each']
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# ...

# %% [markdown]
# #### Subtask: Convert non-int values in "Quantity Ordered" and "Price Each" to int

# %%
all_data['Quantity Ordered'] = all_data['Quantity Ordered'].astype('int32')
all_data['Price Each'] = all_data['Price Each'].astype('float')

#Alternative
#all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered']) #make int
#all_data['Price Each'] = pd.to_numeric(all_data['Price Each']) #make float
# Out:
# <ipython-input-17-96ec08343c3e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Quantity Ordered'] = all_data['Quantity Ordered'].astype('int32')
# <ipython-input-17-96ec08343c3e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Price Each'] = all_data['Price Each'].astype('float')

# %% [markdown]
# ### Question 1: What's the best month for sales? How much was earned per month?

# %%
all_data.groupby('Month').sum()
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
results = all_data.groupby('Month').sum()

# %%
import matplotlib.pyplot as plt

months = range (1,13)


plt.bar(months, results['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD')
plt.xlabel('Month')

plt.ticklabel_format(style='plain')
plt.show()

# %% [markdown]
# ### Question 2: What city has the highest sales?

# %% [markdown]
# #### Subtask: Create a "City" column

# %%
#Use .apply()

all_data['City'] = all_data['Purchase Address'].apply(lambda x: x.split(',')[1] + ' ' + x.split(',')[2].split(' ')[1])

all_data.head()
# Out:
# <ipython-input-30-a0f557009a3e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['City'] = all_data['Purchase Address'].apply(lambda x: x.split(',')[1] + ' ' + x.split(',')[2].split(' ')[1])
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# ...

# %% [markdown]
# #### Bonus

# %%
#Use .apply()

def get_city(address):
    return address.split(',')[1]
def get_state(address):
    return address.split(',')[2].split(' ')[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: get_city(x) + ' ' + get_state(x))

#Using function
all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")

# %%
all_data.groupby('City').sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-382a78e4a749> in <module>
# ----> 1 all_data.groupby(by='City').sum()
#
# NameError: name 'all_data' is not defined

# %%
results_city = all_data.groupby('City').sum()

cities = sorted(all_data['City'].unique())
#Keith Solution
#cities = [city for city, df in all_data.groupby(['City'])]

plt.bar(cities, results_city['Sales'])
plt.xticks(cities, rotation='vertical', size=8)
plt.ylabel('Sales in USD')
plt.xlabel('City')
plt.show()

# %% [markdown]
# ### Question 3: What time should we display advestisements to maximize likelihood of customer's buying product?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#               City
# 0        Dallas TX
# 1        Boston MA
# 2   Los Angeles CA
# 3   Los Angeles CA
# 4   Los Angeles CA

# %% [markdown]
# #### Subtask: Convert Data type of "Order Date" column

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date']) # to date time
# Out:
# <ipython-input-53-7bcab20d11a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Order Date'] = pd.to_datetime(all_data['Order Date']) # to date time

# %% [markdown]
# #### Subtask: Create "Hour" column

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data['Minute'] = all_data['Order Date'].dt.minute
all_data.head()
# Out:
# <ipython-input-56-ec9426e6037f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Hour'] = all_data['Order Date'].dt.hour
# <ipython-input-56-ec9426e6037f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Minute'] = all_data['Order Date'].dt.minute
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# ...

# %%
hours = [hour for hour, df in all_data.groupby(['Hour'])]

plt.plot(hours, all_data.groupby(['Hour']).count())
plt.xticks(hours, rotation=45)
plt.ylabel('No. of Transactions')
plt.xlabel('Hour')
plt.grid()
plt.show

# My recommendation is to advertise at 10am-11am and 5pm-6pm
# That is 2 hours before the peak
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Question 4: What products are most often sold together?

# %%
#Return rows by boolean value; 'Keep' to mark True or False
df = all_data[all_data['Order ID'].duplicated(keep=False)]

#Get each 'Product' and join
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

df = df[['Order ID', 'Grouped']].drop_duplicates()

df.head()
# Out:
# <ipython-input-106-894158c0309c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#     Order ID                                            Grouped
# 2     176560                      Google Phone,Wired Headphones
# 17    176574                  Google Phone,USB-C Charging Cable
# 29    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 31    176586                AAA Batteries (4-pack),Google Phone
# 118   176672      Lightning Charging Cable,USB-C Charging Cable

# %%
#https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary

from itertools import combinations
from collections import Counter

count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %% [markdown]
# ### Question 5: What product sold the most? Why do you think it sold the most?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#               City  Hour  Minute
# 0        Dallas TX     8      46
# ...

# %% [markdown]
# #### Based on quantity

# %%
product_group = all_data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']
quantity_ordered.head()
# Out:
# Product
# 20in Monitor               4129
# 27in 4K Gaming Monitor     6244
# 27in FHD Monitor           7550
# 34in Ultrawide Monitor     6199
# AA Batteries (4-pack)     27635
# Name: Quantity Ordered, dtype: int32

# %%
products = [product for product, df in product_group]

plt.bar(products, quantity_ordered)
plt.xticks(products, rotation='vertical')
plt.ylabel('Quantity Sold')
plt.xlabel('Product')
#plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Product Prices

# %%
prices = all_data.groupby('Product').mean()['Price Each']

print(prices)
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %% [markdown]
# #### Adding Prices in the Quantity Sold per Product

# %%
import numpy as np

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products, quantity_ordered)
ax2.plot(products, prices, 'r-')

ax1.set_xlabel('Product')
ax1.set_ylabel('Quantity Sold')
ax2.set_ylabel('Price (USD)', color='r')
ax1.set_xticklabels(products, rotation='vertical', size=8)

plt.show()
# Out:
# <ipython-input-144-157688edc61f>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products, rotation='vertical', size=8)

# %% [markdown]
# #### Based on Sales

# %%
product_group = all_data.groupby('Product')
sales = product_group.sum()['Sales']
sales.head()
# Out:
# Product
# 20in Monitor               454148.71
# 27in 4K Gaming Monitor    2435097.56
# 27in FHD Monitor          1132424.50
# 34in Ultrawide Monitor    2355558.01
# AA Batteries (4-pack)      106118.40
# Name: Sales, dtype: float64

# %%
products = [product for product, df in product_group]

plt.bar(products, sales)
plt.xticks(products, rotation='vertical')
plt.ylabel('Sales in USD')
plt.xlabel('Product')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Adding Prices in the Sales per Product

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products, sales)
ax2.plot(products, prices, 'r-')

ax1.set_xlabel('Product')
ax1.set_ylabel('Sales (USD)')
ax2.set_ylabel('Price (USD)', color='r')
ax1.set_xticklabels(products, rotation='vertical', size=8)

plt.show()
# Out:
# <ipython-input-146-bbbb555ad198>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products, rotation='vertical', size=8)
